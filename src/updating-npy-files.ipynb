# %%
import numpy as np
import shapely.geometry

# %%
file1 = '../models/interface/nz-interface-hik-focmec_v1.npy'
# 1. Load the old data (triggers the warning)
dat = np.load(file1, allow_pickle=True)

# 2. Save the object again (creates a new, compatible pickle)
np.save(file1, dat)

# %%
file2 = '../models/interface/nz-interface-puy-focmec_v1.npy'
# 1. Load the old data (triggers the warning)
dat = np.load(file2, allow_pickle=True)

# 2. Save the object again (creates a new, compatible pickle)
np.save(file2, dat)
